# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,ConfusionMatrixDisplay,confusion_matrix
import mlflow.sklearn
import seaborn as sns
from sklearn.datasets import load_wine
import pandas as pd
import matplotlib.pyplot as plt

# %%
def load_data()-> pd.DataFrame:
     wine_data=load_wine()
     df=pd.DataFrame(wine_data.data,columns=wine_data.feature_names)
     df['target'] = wine_data.target
     return df

# %%
def cleaned_data(df:pd.DataFrame) -> pd.DataFrame:
    num_cols = df.select_dtypes(include='number').drop(columns=['target']).columns.to_list()
    q1=df[num_cols].quantile(0.25)
    q3=df[num_cols].quantile(0.75)
    iqr = q3 - q1
    upper_bound=q3+(1.5*iqr)
    lower_bound= q1 - (1.5 * iqr)
    outlier_mask= (df[num_cols] > upper_bound)|(df[num_cols] < lower_bound)
    print("outlier in the dataset:",outlier_mask.sum().sum())
    df_cleaned=df[num_cols].clip(upper=upper_bound,lower=lower_bound,axis=1)
    df_cleaned['target'] = df['target']
    print(f"Data cleaned and clipped. Shape: {df_cleaned.shape}")
    return df_cleaned

# %%
def column_(df:pd.DataFrame) -> pd.DataFrame :
    df=df.rename(columns={'od280/od315_of_diluted_wines': 'diluted_wines'})
    cor=df.corr()
    plt.figure(figsize=(10,8))
    s=sns.heatmap(cor, cmap='coolwarm', annot=True, center=0, vmin=-1, vmax=1)
    s.plot()
    plt.title("corelation of features")
    return df

# %%
df_raw = load_data()
df_clean= cleaned_data(df_raw)
df_column=column_(df_clean)
print(df_column.head())
# Out:
# outlier in the dataset: 21
# Data cleaned and clipped. Shape: (178, 14)
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    diluted_wines  proline  target
# 0           3.92   1065.0       0
# 1           3.40   1050.0       0
# 2           3.17   1185.0       0
# 3           3.45   1480.0       0
# 4           2.93    735.0       0

# %%
num = ['hue', 'diluted_wines', 'proline', 'total_phenols', 'flavanoids']
for n in num:
    plt.figure(figsize=(8,8))
    sns.boxplot(data=df_column ,x='target',y=n)
    plt.title(f'distribution of target against{n}')
    plt.plot()

# %%
mlflow.end_run()
with mlflow.start_run():
    
        x=df_column[num]
        y=df_column['target']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)


rf = RandomForestClassifier(
    n_estimators=100,
    criterion="gini",
    max_depth=10,
    min_samples_split=2,
    min_samples_leaf=1,
    max_features="sqrt",
    max_leaf_nodes=10,        # Changed : to =
    min_impurity_decrease=0.0, # 10 was too high; it would stop the model from growing
    bootstrap=True,
    n_jobs=-1,                 # -1 uses all your CPU cores (faster)
    random_state=42,
    verbose=0,                 # 100 is way too much text; 0 or 1 is better
    max_samples=None           # 9.9 is invalid (must be between 0 and 1.0)
)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
acc=accuracy_score(y_pred,y_test)
cm=confusion_matrix(y_pred,y_test)
cmd=ConfusionMatrixDisplay(confusion_matrix=cm)
cr=classification_report(y_pred,y_test)
with open("classification_report.txt",'w') as f:
        f.write(cr)
mlflow.log_artifact("classification_report.txt")
plt.figure(figsize=(8,8))
cmd.plot(cmap='Blues')
plt.title("random forest wine data ")
plt.savefig("cmd.jpg")
plt.title("Random Forest Wine Data")
plt.savefig("confusion_matrix.png")
mlflow.log_artifact("confusion_matrix.png")
plt.show()
mlflow.log_param('min_samples_leaf',10)
mlflow.log_param(' max_leaf_nodes',10)
print(f"accuracy score is :{acc:.2f}")
# Out:
# accuracy score is :0.97

# %%
mlflow.sklearn.log_model(rf, "wine_rf_model_97")
# Out:
# 2025/12/19 22:56:30 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/12/19 22:57:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
import pickle
with open("wine_type.pkl",'wb') as f:
    pickle.dump(rf,f)

print("model saved successfully ")
# Out:
# model saved successfully

# %%
pip install fastapi
# Out:
# Requirement already satisfied: fastapi in c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages (0.116.2)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 25.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages (from fastapi) (0.46.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages (from fastapi) (2.11.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages (from starlette<0.49.0,>=0.40.0->fastapi) (4.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (1.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aishwarya\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (1.3.1)

# %%
import uvicorn
from fastapi import FastAPI
import pickle 
import nest_asyncio
import pandas as pd  # <--- Yeh missing tha
from pydantic import BaseModel

nest_asyncio.apply()
app = FastAPI()

# Model load karein
with open("wine_type.pkl", 'rb') as f:
    model = pickle.load(f)

# Input class (5 columns as you mentioned)
class wine_input(BaseModel):
    hue: float
    diluted_wines: float
    proline: float
    total_phenols: float
    flavanoids: float

@app.get("/")
def home():
    return {"message": "Wine Prediction API is Running!"}

@app.post("/predict")
def predict(data: wine_input):
    # 1. model_dump() ke saath () lagayein
    # 2. Seedha DataFrame banayein, double list ki zaroorat nahi
    input_df = pd.DataFrame([data.model_dump()])
    
    # 3. Prediction karein
    prediction = model.predict(input_df)

    return {"wine_class": int(prediction[0])}

if __name__ == "__main__":
    uvicorn.run(app, host="127.0.0.1", port=8000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 39
#      36     return {"wine_class": int(prediction[0])}
#      38 if __name__ == "__main__":
# ---> 39     uvicorn.run(app, host="127.0.0.1", port=8000)
#
# File c:\Users\AISHWARYA\AppData\Local\Programs\Python\Python310\lib\site-packages\uvicorn\main.py:517, in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, timeout_keep_alive, timeout_graceful_shutdown, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     514 if app_dir is not None:
#     515     sys.path.insert(0, app_dir)
# --> 517 config = Config(
#     518     app,
#     519     host=host,
#     520     port=port,
#     521     uds=uds,
#     522     fd=fd,
#     523     loop=loop,
#     524     http=http,
#     525     ws=ws,
#     526     ws_max_size=ws_max_size,
#     527     ws_max_queue=ws_max_queue,
#     528     ws_ping_interval=ws_ping_interval,
#     529     ws_ping_timeout=ws_ping_timeout,
#     530     ws_per_message_deflate=ws_per_message_deflate,
#     531     lifespan=lifespan,
#     532     interface=interface,
#     533     reload=reload,
#     534     reload_dirs=reload_dirs,
#     535     reload_includes=reload_includes,
#     536     reload_excludes=reload_excludes,
#     537     reload_delay=reload_delay,
#     538     workers=workers,
#     539     env_file=env_file,
#     540     log_config=log_config,
#     541     log_level=log_level,
#     542     access_log=access_log,
#     543     proxy_headers=proxy_headers,
#     544     server_header=server_header,
#     545     date_header=date_header,
#     546     forwarded_allow_ips=forwarded_allow_ips,
#     547     root_path=root_path,
#     548     limit_concurrency=limit_concurrency,
#     549     backlog=backlog,
#     550     limit_max_requests=limit_max_requests,
#     551     timeout_keep_alive=timeout_keep_alive,
#     552     timeout_graceful_shutdown=timeout_graceful_shutdown,
#     553     ssl_keyfile=ssl_keyfile,
#     554     ssl_certfile=ssl_certfile,
#     555     ssl_keyfile_password=ssl_keyfile_password,
#     556     ssl_version=ssl_version,
#     557     ssl_cert_reqs=ssl_cert_reqs,
#     558     ssl_ca_certs=ssl_ca_certs,
#     559     ssl_ciphers=ssl_ciphers,
#     560     headers=headers,
#     561     use_colors=use_colors,
#     562     factory=factory,
#     563     h11_max_incomplete_event_size=h11_max_incomplete_event_size,
#     564 )
#     565 server = Server(config=config)
#     567 if (config.reload or config.workers > 1) and not isinstance(app, str):
#
# File c:\Users\AISHWARYA\AppData\Local\Programs\Python\Python310\lib\site-packages\uvicorn\config.py:274, in Config.__init__(self, app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, env_file, log_config, log_level, access_log, use_colors, interface, reload, reload_dirs, reload_delay, reload_includes, reload_excludes, workers, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, limit_max_requests, backlog, timeout_keep_alive, timeout_notify, timeout_graceful_shutdown, callback_notify, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, factory, h11_max_incomplete_event_size)
#     271 self.h11_max_incomplete_event_size = h11_max_incomplete_event_size
#     273 self.loaded = False
# --> 274 self.configure_logging()
#     276 self.reload_dirs: list[Path] = []
#     277 self.reload_dirs_excludes: list[Path] = []
#
# File c:\Users\AISHWARYA\AppData\Local\Programs\Python\Python310\lib\site-packages\uvicorn\config.py:366, in Config.configure_logging(self)
#     364         self.log_config["formatters"]["default"]["use_colors"] = self.use_colors
#     365         self.log_config["formatters"]["access"]["use_colors"] = self.use_colors
# --> 366     logging.config.dictConfig(self.log_config)
#     367 elif isinstance(self.log_config, str) and self.log_config.endswith(".json"):
#     368     with open(self.log_config) as file:
#
# File c:\Users\AISHWARYA\AppData\Local\Programs\Python\Python310\lib\logging\config.py:810, in dictConfig(config)
#     808 def dictConfig(config):
#     809     """Configure logging using a dictionary."""
# --> 810     dictConfigClass(config).configure()
#
# File c:\Users\AISHWARYA\AppData\Local\Programs\Python\Python310\lib\logging\config.py:538, in DictConfigurator.configure(self)
#     535 else:
#     536     disable_existing = config.pop('disable_existing_loggers', True)
# --> 538     _clearExistingHandlers()
#     540     # Do formatters first - they don't refer to anything else
#     541     formatters = config.get('formatters', EMPTY_DICT)
#
# File c:\Users\AISHWARYA\AppData\Local\Programs\Python\Python310\lib\logging\config.py:275, in _clearExistingHandlers()
#     273 """Clear and close existing handlers"""
#     274 logging._handlers.clear()
# --> 275 logging.shutdown(logging._handlerList[:])
#     276 del logging._handlerList[:]
#
# File c:\Users\AISHWARYA\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py:2173, in shutdown(handlerList)
#    2171 try:
#    2172     h.acquire()
# -> 2173     h.flush()
#    2174     h.close()
#    2175 except (OSError, ValueError):
#    2176     # Ignore errors which might be caused
#    2177     # because handlers have been closed but
#    2178     # references to them are still around at
#    2179     # application exit.
#
# File c:\Users\AISHWARYA\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py:1082, in StreamHandler.flush(self)
#    1080 try:
#    1081     if self.stream and hasattr(self.stream, "flush"):
# -> 1082         self.stream.flush()
#    1083 finally:
#    1084     self.release()
#
# File c:\Users\AISHWARYA\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:604, in OutStream.flush(self)
#     593 """trigger actual zmq send
#     594
#     595 send will happen in the background thread
#     596 """
#     597 if (
#     598     self.pub_thread
#     599     and self.pub_thread.thread is not None
#    (...)
#     602 ):
#     603     # request flush on the background thread
# --> 604     self.pub_thread.schedule(self._flush)
#     605     # wait for flush to actually get through, if we can.
#     606     evt = threading.Event()
#
# File c:\Users\AISHWARYA\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:267, in IOPubThread.schedule(self, f)
#     265     self._events.append(f)
#     266     # wake event thread (message content is ignored)
# --> 267     self._event_pipe.send(b"")
#     268 else:
#     269     f()
#
# File c:\Users\AISHWARYA\AppData\Local\Programs\Python\Python310\lib\site-packages\zmq\sugar\socket.py:698, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     691         data = zmq.Frame(
#     692             data,
#     693             track=track,
#     694             copy=copy or None,
#     695             copy_threshold=self.copy_threshold,
#     696         )
#     697     data.group = group
# --> 698 return super().send(data, flags=flags, copy=copy, track=track)
#
# File _zmq.py:1081, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1129, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1397, in zmq.backend.cython._zmq._send_copy()
#
# File _zmq.py:169, in zmq.backend.cython._zmq._check_rc()
#
# KeyboardInterrupt:
